# %% [markdown]
# # Быстрый старт в анализ данных
#
# **с помощью `Pandas` и `Scikit-learn`,**
# **а также `numpy` и `matplotlib`**
#
# - `numpy` – матричные операции
# - `matplotlib` – научная графика
# - `pandas` – таблицы (DataFrame) для анализа данных
# - `scikit-learn` – алгоритмы машинного обучения

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
#url = 'https://www.kaggle.com/mdhrumil/top-5000-youtube-channels-data-from-socialblade#data.csv'
#data = pd.read_csv(url, sep = ', ', engine='python')'
data = pd.read_csv('c:/Users/Novozhilova Nastya/AnacondaProjects/Machine_learning/Building_Permits.csv', sep = ',', engine = 'python')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# 5       201706149344            8            otc alterations permit
# 6       201706300814            8            otc alterations permit
# 7            M803667            8            otc alterations permit
# 8            M804227            8            otc alterations permit
# 9            M804767            8            otc alterations permit
# 10           M805287            8            otc alterations permit
# 11           M805907            8            otc alterations permit
# 12           M806447            8            otc alterations permit
# ...

# %%
print(data)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# 5       201706149344            8            otc alterations permit
# 6       201706300814            8            otc alterations permit
# 7            M803667            8            otc alterations permit
# 8            M804227            8            otc alterations permit
# 9            M804767            8            otc alterations permit
# 10           M805287            8            otc alterations permit
# 11           M805907            8            otc alterations permit
# 12           M806447            8            otc alterations permit
# ...

# %%
data = data.drop(['Block', 'Lot', 'Street Number Suffix', 'Unit', 'Unit Suffix', 'Structural Notification','Number of Existing Stories', 'Number of Proposed Stories','Voluntary Soft-Story Retrofit', 'Fire Only Permit', 'Permit Expiration Date', 'Revised Cost', 'Existing Units','Proposed Use', 'Proposed Units', 'Plansets', 'TIDF Compliance', 'Proposed Construction Type', 'Proposed Construction Type Description', 'Site Permit', 'Supervisor District', 'Neighborhoods - Analysis Boundaries', 'Zipcode', 'Location', 'Record ID'],axis = 1)

# %%
data
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# 5       201706149344            8            otc alterations permit
# 6       201706300814            8            otc alterations permit
# 7            M803667            8            otc alterations permit
# 8            M804227            8            otc alterations permit
# 9            M804767            8            otc alterations permit
# 10           M805287            8            otc alterations permit
# 11           M805907            8            otc alterations permit
# 12           M806447            8            otc alterations permit
# ...

# %%
data.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date  Street Number Street Name Street Suffix  \
# 0           05/06/2015            140       Ellis            St
# 1           04/19/2016            440       Geary            St
# 2           05/27/2016           1647     Pacific            Av
# 3           11/07/2016           1230     Pacific            Av
# 4           11/28/2016            950      Market            St
#
#                                          Description Current Status  \
# 0  ground fl facade: to erect illuminated, electr...        expired
# ...

# %%
data.tail()
# Out:
#        Permit Number  Permit Type  Permit Type Definition  \
# 198895       M862628            8  otc alterations permit
# 198896  201712055595            8  otc alterations permit
# 198897       M863507            8  otc alterations permit
# 198898       M863747            8  otc alterations permit
# 198899       M864287            8  otc alterations permit
#
#        Permit Creation Date  Street Number Street Name Street Suffix  \
# 198895           12/05/2017           1228  Montgomery            St
# 198896           12/05/2017            580        Bush            St
# 198897           12/06/2017           1568     Indiana            St
# 198898           12/06/2017            795      Sutter            St
# 198899           12/07/2017            838     Pacific            Av
#
#                                 Description Current Status  \
# 198895                         street space         issued
# 198896  fire alarm upgrade ref 201704123852         issued
# ...

# %%
print(data.shape)
print(data.columns)
# Out:
# (198900, 18)
# Index(['Permit Number', 'Permit Type', 'Permit Type Definition',
#        'Permit Creation Date', 'Street Number', 'Street Name', 'Street Suffix',
#        'Description', 'Current Status', 'Current Status Date', 'Filed Date',
#        'Issued Date', 'Completed Date', 'First Construction Document Date',
#        'Estimated Cost', 'Existing Use', 'Existing Construction Type',
#        'Existing Construction Type Description'],
#       dtype='object')

# %%
#data.columns = []

# %%
data.index
# Out:
# RangeIndex(start=0, stop=198900, step=1)

# %%
data.at[8, 'Street Name']
# Out:
# 'Fell'

# %%
data['Street Name']
# Out:
# 0               Ellis
# 1               Geary
# 2             Pacific
# 3             Pacific
# 4              Market
# 5             Indiana
# 6                11th
# 7              Revere
# 8                Fell
# 9              Alpine
# 10            Sanchez
# 11               Fell
# 12               25th
# 13               27th
# 14               Pine
# 15             Powell
# 16         Montgomery
# 17               21st
# 18                Bay
# 19            Corbett
# 20             Fulton
# 21               26th
# 22             Taylor
# 23            Filbert
# 24           Charlton
# 25               29th
# 26               17th
# 27            Shrader
# 28               06th
# 29             Powell
#              ...
# 198870    North Point
# 198871        Clayton
# 198872         Market
# 198873       Tompkins
# 198874         Duncan
# 198875          Hayes
# 198876        Stanyan
# 198877          Lobos
# 198878           24th
# 198879          Paris
# ...

# %%
data['Street Name'][12]
# Out:
# '25th'

# %%
data['Estimated Cost'].dtype.name
# Out:
# 'float64'

# %%
type(data['Street Name'][3])
# Out:
# str

# %%
type(data['Street Name'])
# Out:
# pandas.core.series.Series

# %%
data[['Estimated Cost', 'Street Name']].head()
# Out:
#    Estimated Cost Street Name
# 0          4000.0       Ellis
# 1             1.0       Geary
# 2         20000.0     Pacific
# 3          2000.0     Pacific
# 4        100000.0      Market

# %%
#data.index = xrange(32561)
#data.index

# %%
data.describe()
# Out:
#          Permit Type  Street Number  Estimated Cost  \
# count  198900.000000  198900.000000    1.608340e+05
# mean        7.522323    1121.728944    1.689554e+05
# std         1.457451    1135.768948    3.630386e+06
# min         1.000000       0.000000    1.000000e+00
# 25%         8.000000     235.000000    3.300000e+03
# 50%         8.000000     710.000000    1.100000e+04
# 75%         8.000000    1700.000000    3.500000e+04
# max         8.000000    8400.000000    5.379586e+08
#
#        Existing Construction Type
# count               155534.000000
# mean                     4.072878
# std                      1.585756
# min                      1.000000
# 25%                      3.000000
# 50%                      5.000000
# 75%                      5.000000
# max                      5.000000

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .5, figsize = (20, 20))
pass

# %%
data.corr()
# Out:
#                             Permit Type  Street Number  Estimated Cost  \
# Permit Type                    1.000000      -0.002281       -0.120878
# Street Number                 -0.002281       1.000000       -0.011152
# Estimated Cost                -0.120878      -0.011152        1.000000
# Existing Construction Type    -0.004265       0.228214       -0.048703
#
#                             Existing Construction Type
# Permit Type                                  -0.004265
# Street Number                                 0.228214
# Estimated Cost                               -0.048703
# Existing Construction Type                    1.000000

# %%
plt.plot(data['Street Number'], data['Estimated Cost'],  'o', alpha = 0.5)
plt.xlabel('Street Number')
plt.ylabel('Estimated Cost')
plt.title('Street Number vs Estimated Cost')
pass

# %%
data['Street Suffix'] == 'Av'
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4         False
# 5         False
# 6          True
# 7          True
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19         True
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25         True
# 26         True
# 27        False
# 28         True
# 29        False
#           ...
# 198870    False
# 198871    False
# 198872    False
# 198873     True
# 198874    False
# 198875    False
# 198876    False
# 198877    False
# 198878    False
# 198879    False
# 198880     True
# 198881    False
# 198882     True
# 198883    False
# 198884    False
# 198885     True
# 198886    False
# 198887    False
# 198888    False
# 198889     True
# 198890    False
# 198891     True
# 198892    False
# 198893    False
# ...

# %%
plt.figure(figsize = (30, 10))

plt.scatter(data[data['Estimated Cost'] <= 15000]['Street Number'],
            data[data['Estimated Cost'] <= 15000]['Existing Construction Type'],
            alpha = 0.5,
            label = '<=15K',
            color = 'b')

plt.scatter(data[data['Estimated Cost'] >= 15000]['Street Number'],
            data[data['Estimated Cost'] >= 15000]['Existing Construction Type'],
            alpha = 0.5,
            label = '>=15K',
            color = 'r')

plt.xlabel('Street Number')
plt.xticks(range(100))
plt.xlim(0, 99)
plt.ylabel('Existing Construction Type')
plt.legend()
plt.grid()

# %%
np.random.seed(0)
constract_type_rnd = data['Existing Construction Type'] + np.random.rand(data.shape[0]) - .5

plt.figure(figsize = (20, 10))

plt.scatter(data[data['Estimated Cost'] <= 15000]['Street Name'],
            data[data['Estimated Cost'] <= 15000]['Existing Construction Type'],
            alpha = 0.5,
            label = '<=15K',
            color = 'b')

plt.scatter(data[data['Estimated Cost'] >= 15000]['Street Name'],
            data[data['Estimated Cost'] >= 15000]['Existing Construction Type'],
            alpha = 0.5,
            label = '>=15K',
            color = 'r')

plt.xlabel('Street Name')
plt.xticks(range(17))
plt.xlim(0, 17)
plt.ylabel('Existing Construction Type')
plt.title('Data')
plt.grid()

# %%
plt.figure(figsize = (20, 10))

plt.scatter(data[data['Current Status'] == 'complete']['Permit Creation Date'],
            data[data['Current Status'] == 'complete']['Current Status Date'],
            alpha = 0.5,
            label = 'complete',
            color = 'b')

plt.scatter(data[data['Current Status'] == 'issued']['Permit Creation Date'],
            data[data['Current Status'] == 'issued']['Current Status Date'],
            alpha = 0.5,
            label = 'issued',
            color = 'r')

plt.xlabel('Permit Creation Date')
plt.xticks(range(10))
plt.xlim(0, 9)
plt.ylabel('Current Status Date')
plt.yticks(range(20))
plt.ylim(0, 19)
plt.grid()

# %%
data.describe(include = ['object'])
# Out:
#        Permit Number  Permit Type Definition Permit Creation Date Street Name  \
# count         198900                  198900               198900      198900
# unique        181495                       8                 1291        1704
# top     201602179765  otc alterations permit           09/15/2017      Market
# freq             101                  178844                  413        5443
#
#        Street Suffix   Description Current Status Current Status Date  \
# count         196132        198610         198900              198900
# unique            21        134272             14                1307
# top               St  street space       complete          09/15/2017
# freq          138358         22163          97077                 474
#
#         Filed Date Issued Date Completed Date  \
# count       198900      183960          97191
# unique        1288        1289           1300
# top     09/15/2017  06/15/2016     10/30/2015
# ...

# %%
data.describe(include = 'all')
# Out:
#        Permit Number    Permit Type  Permit Type Definition  \
# count         198900  198900.000000                  198900
# unique        181495            NaN                       8
# top     201602179765            NaN  otc alterations permit
# freq             101            NaN                  178844
# mean             NaN       7.522323                     NaN
# std              NaN       1.457451                     NaN
# min              NaN       1.000000                     NaN
# 25%              NaN       8.000000                     NaN
# 50%              NaN       8.000000                     NaN
# 75%              NaN       8.000000                     NaN
# max              NaN       8.000000                     NaN
#
#        Permit Creation Date  Street Number Street Name Street Suffix  \
# count                198900  198900.000000      198900        196132
# unique                 1291            NaN        1704            21
# ...

# %%
data['Existing Use'].unique()
# Out:
# array(['tourist hotel/motel', 'retail sales', '1 family dwelling',
#        'apartments', nan, '2 family dwelling', 'church', 'storage shed',
#        'office', 'vacant lot', 'food/beverage hndlng',
#        'residential hotel', 'filling/service stn', 'workshop commercial',
#        'clinics-medic/dental', 'misc group residns.', 'hospital', 'club',
#        'barber/beauty salon', 'warehouse,no frnitur', 'school',
#        'artist live/work', 'manufacturing', 'garment shops',
#        'public assmbly other', 'auto repairs', 'lending institution',
#        'museum', 'warehouse, furniture', 'prkng garage/private',
#        'antenna', 'health studios & gym', 'massage parlor',
#        'printing plant', 'parking lot', 'workshop residential',
#        'power plant', 'tower', 'mortuary', 'animal sale or care',
#        'laundry/laundromat', 'nite club', 'paint store',
#        'recreation bldg', 'theater', 'prkng garage/public', 'sign',
# ...

# %%
data['Street Name'].unique()
# Out:
# array(['Ellis', 'Geary', 'Pacific', ..., 'Chain Of Lakes', 'Unknown',
#        'Ignacio'], dtype=object)

# %%
for name in data['Street Name'].unique():
    print(name, data['Street Number'][data['Street Name'] == name].iloc[0])
# Out:
# Ellis 140
# Geary 440
# Pacific 1647
# Market 950
# Indiana 800
# 11th 1291
# Revere 1465
# Fell 2094
# Alpine 89
# Sanchez 106
# 25th 4082
# 27th 681
# Pine 2761
# Powell 840
# Montgomery 220
# 21st 3707
# Bay 1307
# Corbett 263
# Fulton 1624
# 26th 3410
# Taylor 2150
# Filbert 2824
# Charlton 1
# 29th 1435
# 17th 331
# Shrader 120
# 06th 1512
# 18th 3830
# Capp 563
# Lansing 76
# 15th 1810
# Eddy 1445
# Church 1383
# San Jose 681
# 30th 606
# Steiner 3325
# 36th 700
# 04th 249
# Jackson 2379
# Saint Charles 247
# Webster 2843
# Divisadero 2615
# Cotter 252
# Felton 938
# Fillmore 896
# Hyde 2718
# 03rd 264
# Sutter 861
# King 274
# Mill 66
# 12th 1730
# Gough 1809
# Washington 3953
# Sacramento 1571
# 19th 3320
# Cole 718
# Mission 5050
# Hampshire 624
# Wool 156
# Jefferson 1856
# 16th 2563
# Leavenworth 1455
# Ofarrell 165
# 33rd 835
# Francisco 1304
# Howard 1202
# Greenwich 2250
# California 1700
# Carolina 737
# Mariposa 595
# Clay 3778
# Castro 2
# Executive Park 250
# ...

# %% [markdown]
# ## Задача

# %%
data.drop(['Issued Date','First Construction Document Date'], axis = 1) # так тоже работает
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# 5       201706149344            8            otc alterations permit
# 6       201706300814            8            otc alterations permit
# 7            M803667            8            otc alterations permit
# 8            M804227            8            otc alterations permit
# 9            M804767            8            otc alterations permit
# 10           M805287            8            otc alterations permit
# 11           M805907            8            otc alterations permit
# 12           M806447            8            otc alterations permit
# ...

# %% [markdown]
# # Готовим данные

# %%
data['Permit Creation Date'].dtype.name
# Out:
# 'object'

# %%
data['Existing Construction Type Description'].dtype.name
# Out:
# 'object'

# %%
#categorical_columns = []
#numerical_columns = []
#for c in data.columns:
#    if data[c].dtype.name == 'object':
#        categorical_columns.append(c)
#    else:
#        numerical_columns.append(c)

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['Permit Number', 'Permit Type Definition', 'Permit Creation Date', 'Street Name', 'Street Suffix', 'Description', 'Current Status', 'Current Status Date', 'Filed Date', 'Issued Date', 'Completed Date', 'First Construction Document Date', 'Existing Use', 'Existing Construction Type Description']
# ['Permit Type', 'Street Number', 'Estimated Cost', 'Existing Construction Type']

# %%
for c in categorical_columns:
    print(c, data[c].unique())
# Out:
# Permit Number ['201505065519' '201604195146' '201605278609' ... 'M863507' 'M863747'
#  'M864287']
# Permit Type Definition ['sign - erect' 'additions alterations or repairs'
#  'otc alterations permit' 'demolitions' 'wall or painted sign'
#  'new construction' 'grade or quarry or fill or excavate'
#  'new construction wood frame']
# Permit Creation Date ['05/06/2015' '04/19/2016' '05/27/2016' ... '02/21/2018' '02/22/2018'
#  '02/23/2018']
# Street Name ['Ellis' 'Geary' 'Pacific' ... 'Chain Of Lakes' 'Unknown' 'Ignacio']
# Street Suffix ['St' 'Av' 'Tr' 'Ct' 'Bl' 'Wy' 'Dr' nan 'Rd' 'Cr' 'Pl' 'Ln' 'Hy' 'Pk' 'Al'
#  'Pz' 'Wk' 'Rw' 'So' 'Sw' 'No' 'Hl']
# Description ['ground fl facade: to erect illuminated, electric, wall, single faced sign. n/a for maher ordinance 155-13.'
#  'remove (e) awning and associated signs.'
#  'installation of separating wall' ...
# ...

# %% [markdown]
# ## Обрабатываем пропущенные значения
#
# Если данные содержат пропущенные значения, то имеется две простые альтернативы:
# - удалить столбцы с такими значениями (`data = data.dropna(axis = 1)`),
# - удалить строки с такими значениями (`data = data.dropna(axis = 0)`).
#
# После этого данных может стать совсем мало.
#
# Куда более эффективным (и в то же время по-прежнему простым) методом обычно является заполнение пропущенных значений для каждой количественной переменной их средним или медианным значением.
# Для категориальных признаков пропущенные значения можно заполнить самым популярным значением в столбце.

# %%
data.median(axis = 0)
# Out:
# Permit Type                       8.0
# Street Number                   710.0
# Estimated Cost                11000.0
# Existing Construction Type        5.0
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data[numerical_columns].count(axis = 0)
# Out:
# Permit Type                   198900
# Street Number                 198900
# Estimated Cost                198900
# Existing Construction Type    198900
# dtype: int64

# %%
data[categorical_columns].count(axis = 0)
# Out:
# Permit Number                             198900
# Permit Type Definition                    198900
# Permit Creation Date                      198900
# Street Name                               198900
# Street Suffix                             196132
# Description                               198610
# Current Status                            198900
# Current Status Date                       198900
# Filed Date                                198900
# Issued Date                               183960
# Completed Date                             97191
# First Construction Document Date          183954
# Existing Use                              157786
# Existing Construction Type Description    155534
# dtype: int64

# %%
data['Existing Use'].describe()
# Out:
# count                157786
# unique                   93
# top       1 family dwelling
# freq                  46766
# Name: Existing Use, dtype: object

# %%
type(data['Existing Use'].describe())
# Out:
# pandas.core.series.Series

# %%
data['Existing Use'].describe().top
# Out:
# '1 family dwelling'

# %%
data['Existing Use'] = data['Existing Use'].fillna('1 family dwelling')

# %%
data.describe(include = [object])
# Out:
#        Permit Number  Permit Type Definition Permit Creation Date Street Name  \
# count         198900                  198900               198900      198900
# unique        181495                       8                 1291        1704
# top     201602179765  otc alterations permit           09/15/2017      Market
# freq             101                  178844                  413        5443
#
#        Street Suffix   Description Current Status Current Status Date  \
# count         196132        198610         198900              198900
# unique            21        134272             14                1307
# top               St  street space       complete          09/15/2017
# freq          138358         22163          97077                 474
#
#         Filed Date Issued Date Completed Date  \
# count       198900      183960          97191
# unique        1288        1289           1300
# top     09/15/2017  06/15/2016     10/30/2015
# ...

# %%
data_describe = data.describe(include = [object])
for c in categorical_columns:
    data[c] = data[c].fillna(data_describe[c]['top'])

# %%
data.describe(include = [object])
# Out:
#        Permit Number  Permit Type Definition Permit Creation Date Street Name  \
# count         198900                  198900               198900      198900
# unique        181495                       8                 1291        1704
# top     201602179765  otc alterations permit           09/15/2017      Market
# freq             101                  178844                  413        5443
#
#        Street Suffix   Description Current Status Current Status Date  \
# count         198900        198900         198900              198900
# unique            21        134272             14                1307
# top               St  street space       complete          09/15/2017
# freq          141126         22453          97077                 474
#
#         Filed Date Issued Date Completed Date  \
# count       198900      198900         198900
# unique        1288        1289           1300
# top     09/15/2017  06/15/2016     10/30/2015
# ...

# %% [markdown]
# ## Векторизация
#
# Нужно что-то сделать с категориальными (номинальными) признаками

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] < 50]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 50]
print(binary_columns, nonbinary_columns)
# Out:
# ['Permit Type Definition', 'Street Suffix', 'Current Status', 'Existing Construction Type Description'] ['Permit Number', 'Permit Creation Date', 'Street Name', 'Description', 'Current Status Date', 'Filed Date', 'Issued Date', 'Completed Date', 'First Construction Document Date', 'Existing Use']

# %%
data['Existing Construction Type Description'].unique()
# Out:
# array(['constr type 3', 'constr type 1', 'wood frame (5)',
#        'constr type 2', 'constr type 4'], dtype=object)

# %%
data.at[data['Existing Construction Type Description'] == 'constr type 1', 'Existing Construction Type Description'] = 1
data.at[data['Existing Construction Type Description'] == 'constr type 2', 'Existing Construction Type Description'] = 2
data.at[data['Existing Construction Type Description'] == 'constr type 3', 'Existing Construction Type Description'] = 3
data.at[data['Existing Construction Type Description'] == 'constr type 4', 'Existing Construction Type Description'] = 4
data.at[data['Existing Construction Type Description'] == 'wood frame (5)', 'Existing Construction Type Description'] = 5
data['Existing Construction Type Description'].describe()
# Out:
# count    198900.000000
# mean          4.275018
# std           1.453584
# min           1.000000
# 25%           5.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000
# Name: Existing Construction Type Description, dtype: float64

# %% [markdown]
# К небинарными признакам применим метод _векторизации_,
# который заключается в следующем.
#
# Признак `j`, принимающий `s` значений, заменим на `s` признаков, принимащих значения `0` или `1`,
# в зависимости от того, чему равно значение исходного признака `j`.
#
# Например, в нашей задаче признак `race` принимает 5 различных значений:

# %%
data['Existing Construction Type Description'].unique()
# Out:
# array([3, 1, 5, 2, 4], dtype=int64)

# %% [markdown]
# Заменим признак `race` 5 признаками: `race_White`, `race_Black`, ..., `race_Other`.
#
#  - Если признак `race` принимает значение `White`, то признак `race_White` равен `1`, а все остальные равны `0`.
#  - Если признак `race` принимает значение `Black`, то признак `race_Black` равен `1`, а все остальные равны `0`.
#  - и т.д.
#
# Такую векторизацию осуществляет в pandas метод `get_dummies`:

# %%
data_binary = pd.get_dummies(data[binary_columns])
print(data_binary.columns)
# Out:
# Index(['Existing Construction Type Description',
#        'Permit Type Definition_additions alterations or repairs',
#        'Permit Type Definition_demolitions',
#        'Permit Type Definition_grade or quarry or fill or excavate',
#        'Permit Type Definition_new construction',
#        'Permit Type Definition_new construction wood frame',
#        'Permit Type Definition_otc alterations permit',
#        'Permit Type Definition_sign - erect',
#        'Permit Type Definition_wall or painted sign', 'Street Suffix_Al',
#        'Street Suffix_Av', 'Street Suffix_Bl', 'Street Suffix_Cr',
#        'Street Suffix_Ct', 'Street Suffix_Dr', 'Street Suffix_Hl',
#        'Street Suffix_Hy', 'Street Suffix_Ln', 'Street Suffix_No',
#        'Street Suffix_Pk', 'Street Suffix_Pl', 'Street Suffix_Pz',
#        'Street Suffix_Rd', 'Street Suffix_Rw', 'Street Suffix_So',
#        'Street Suffix_St', 'Street Suffix_Sw', 'Street Suffix_Tr',
# ...

# %% [markdown]
# ## Нормализация количественных признаков
#
# Многие алгоритмы машинного обучения чувствительны к масштабированию данных.
# К таким алгоритмам, например, относится метод ближайших соседей, машина опорных векторов и др.
#
# В этом случае количественные признаки полезно _нормализовать_.
# Это можно делать разными способами.
# Например, каждый количественный признак приведем к нулевому среднему и единичному среднеквадратичному отклонению:

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#          Permit Type  Street Number  Estimated Cost  \
# count  198900.000000  198900.000000    1.989000e+05
# mean        7.522323    1121.728944    1.387255e+05
# std         1.457451    1135.768948    3.265147e+06
# min         1.000000       0.000000    1.000000e+00
# 25%         8.000000     235.000000    5.000000e+03
# 50%         8.000000     710.000000    1.100000e+04
# 75%         8.000000    1700.000000    2.500000e+04
# max         8.000000    8400.000000    5.379586e+08
#
#        Existing Construction Type
# count               198900.000000
# mean                     4.275018
# std                      1.453584
# min                      1.000000
# 25%                      5.000000
# 50%                      5.000000
# 75%                      5.000000
# max                      5.000000

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#         Permit Type  Street Number  Estimated Cost  Existing Construction Type
# count  1.989000e+05   1.989000e+05    1.989000e+05                1.989000e+05
# mean   9.652521e-17   4.433301e-17    1.430731e-17               -1.052239e-16
# std    1.000000e+00   1.000000e+00    1.000000e+00                1.000000e+00
# min   -4.475158e+00  -9.876383e-01   -4.248645e-02               -2.253063e+00
# 25%    3.277484e-01  -7.807300e-01   -4.095544e-02                4.987549e-01
# 50%    3.277484e-01  -3.625112e-01   -3.911785e-02                4.987549e-01
# 75%    3.277484e-01   5.091450e-01   -3.483014e-02                4.987549e-01
# max    3.277484e-01   6.408232e+00    1.647154e+02                4.987549e-01

# %% [markdown]
# ## Соединяем все в одну таблицу

# %%
data = pd.concat((data_numerical, data_binary), axis = 1)
print(data.shape)
#print data.columns
# Out:
# (198900, 48)

# %%
data.describe()
# Out:
#         Permit Type  Street Number  Estimated Cost  \
# count  1.989000e+05   1.989000e+05    1.989000e+05
# mean   9.652521e-17   4.433301e-17    1.430731e-17
# std    1.000000e+00   1.000000e+00    1.000000e+00
# min   -4.475158e+00  -9.876383e-01   -4.248645e-02
# 25%    3.277484e-01  -7.807300e-01   -4.095544e-02
# 50%    3.277484e-01  -3.625112e-01   -3.911785e-02
# 75%    3.277484e-01   5.091450e-01   -3.483014e-02
# max    3.277484e-01   6.408232e+00    1.647154e+02
#
#        Existing Construction Type  Existing Construction Type Description  \
# count                1.989000e+05                           198900.000000
# mean                -1.052239e-16                                4.275018
# std                  1.000000e+00                                1.453584
# min                 -2.253063e+00                                1.000000
# 25%                  4.987549e-01                                5.000000
# ...

# %% [markdown]
# # X и y

# %%
X = data.drop(('Existing Construction Type Description'), axis = 1) # выбрасываем столбец 'Existing Construction Type Description'
y = data['Existing Construction Type Description']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['Permit Type', 'Street Number', 'Estimated Cost',
#        'Existing Construction Type',
#        'Permit Type Definition_additions alterations or repairs',
#        'Permit Type Definition_demolitions',
#        'Permit Type Definition_grade or quarry or fill or excavate',
#        'Permit Type Definition_new construction',
#        'Permit Type Definition_new construction wood frame',
#        'Permit Type Definition_otc alterations permit',
#        'Permit Type Definition_sign - erect',
#        'Permit Type Definition_wall or painted sign', 'Street Suffix_Al',
#        'Street Suffix_Av', 'Street Suffix_Bl', 'Street Suffix_Cr',
#        'Street Suffix_Ct', 'Street Suffix_Dr', 'Street Suffix_Hl',
#        'Street Suffix_Hy', 'Street Suffix_Ln', 'Street Suffix_No',
#        'Street Suffix_Pk', 'Street Suffix_Pl', 'Street Suffix_Pz',
#        'Street Suffix_Rd', 'Street Suffix_Rw', 'Street Suffix_So',
#        'Street Suffix_St', 'Street Suffix_Sw', 'Street Suffix_Tr',
# ...

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (198900, 47)
# (198900,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 139230 59670

# %%
139230+59670
# Out:
# 198900

# %% [markdown]
# В библиотеке scikit-learn реализована масса алгоритмов машинного обучения.
#
# #### Некоторые алгоритмы машинного обучения, реализованные в scikit-learn:
#
#  Метод                                     |  Класс
# -------------------------------------------|--------------------------------------------
#  kNN – $k$ ближайших соседей               | `sklearn.neighbors.KNeighborsClassifier`
#  LDA – линейный дискриминантный анализ     | `sklearn.discriminant_analysis.LinearDiscriminantAnalysis`
#  QDA – квадратичный дискриминантный анализ | `sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis`
#  Logistic – логистическая регрессия        | `sklearn.linear_model.LogisticRegression`
#  SVC – машина опорных векторов             | `sklearn.svm.SVC`
#  Tree – деревья решений                    | `sklearn.tree.DecisionTreeClassifier`
#  RF – случайный лес                        | `sklearn.ensemble.RandomForestClassifier`
#  ExtrRF – экстремально случайный лес       | ` `
#  AdaBoost – алгоритм AdaBoost              | `sklearn.ensemble.AdaBoostClassifier`
#  GBT – градиентный бустинг деревьев решений| `sklearn.ensemble.GradientBoostingClassifier`
#  Нейронные сети                            | ` `
#
#
#
#
# #### Основные методы классов, реализующих алгоритмы машинного обучения
# Все алгоритмы выполнены в виде классов, обладающих по крайней мере следующими методами:
#
#
#
#    Метод класса            |  Описание
#  --------------------------|-------------------------------------------------------------
#   `fit(X_train, y_train)`              |  обучение (тренировка) модели на обучающей выборке `X_train`, `y_train`
#   `predict(X)`             |  предсказание на данных `X`
#   `set_params(**params)`   |  установка параметров алгоритма
#   `get_params()`           |  чтение параметров алгоритма
#
#  Заметим, что параметры алгоритмов обучения можно задавать как в конструкторе класса, так и с помощью метода `set_params(**params)`.
#
#  #### Таблица наличия/отсутствия методов для основных алгоритмов машинного обучения:
#
#
#    Методы класса               | kNN | LDA | QDA | Logistic | SVC | Tree | RF | AdaBoost | GBT
#  ------------------------------|-----|-----|-----|----------|-----|------|----|----------|------
#   `fit(X, y)`                  |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `predict(X)`                 |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `predict_proba(X)`           |  +  |  +  |  +  |    +     |     |  +   | +  |    +     |  +
#   `predict_log_proba(X)`       |     |  +  |  +  |    +     |     |  +   | +  |    +     |  +
#   `score(X, y)`                |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `decision_function(X)`       |     |  +  |  +  |    +     |  +  |      |    |    +     |  +
#   `transform(X)`               |     |  +  |     |    +     |     |  +   | +  |          |  +
#   `staged_decision_function(X)`|     |     |     |          |     |      |    |    +     |  +
#   `staged_predict(X)`          |     |     |     |          |     |      |    |    +     |  +
#   `staged_predict_proba(X)`    |     |     |     |          |     |      |    |    +     |  +
#   `staged_score(X, y)`         |     |     |     |          |     |      |    |    +     |  +
#   `set_params(**params)`       |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `get_params()`               |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +

# %% [markdown]
# # $k$NN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 10)
#knn.set_params(n_neighbors=10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#            weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#            weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.0017955900308841484 0.002765208647561589

# %%
err_test = 1 - knn.score(X_test, y_test) # Другой способ

# %%
err_test
# Out:
# 0.002765208647561579

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[ 8411     1     0     0     3]
#  [   43  1155    21     0     0]
#  [    2    34  2854     0    31]
#  [    0     0     3    83    27]
#  [    0     0     0     0 47002]]

# %%
confusion_matrix([0,1,0,1,0], [0,1,0,0,0])
# Out:
# array([[3, 0],
#        [1, 1]], dtype=int64)

# %% [markdown]
# ### Подбор параметров

# %%
# Долго!
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.0010701716584069487 1

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.0011898776604658957

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)

err_train = np.mean(y_train != svc.predict(X_train))
err_test  = np.mean(y_test  != svc.predict(X_test))

print(err_train, err_test)
# Out:
# c:\users\novozhilova nastya\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 2.1547080370609784e-05 3.3517680576504107e-05

# %% [markdown]
# ### Подбор параметров

# %%
from sklearn.grid_search import GridSearchCV
Cs = 10.**np.arange(-5, 5)
gamma_array = 10.**np.arange(-5, 5)
svc = SVC()
grid = GridSearchCV(svc, param_grid = {'C': Cs, 'gamma': gamma_array})
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_C = grid.best_estimator_.C
print(best_cv_err, best_C)

# %%
svc = SVC(C = best_C).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)

# %% [markdown]
# # Random Forest

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.0007038712921065862

# %% [markdown]
# ### Значимость признаков

# %%
a=[1,2,5,70,32,3,4,7,234, 3]
a[-1:3:-1]
# Out:
# [3, 234, 7, 4, 3, 32]

# %%
np.sum(rf.feature_importances_)
# Out:
# 1.0000000000000002

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature 'Existing Construction Type' (0.867691)
#  2. feature 'Street Number' (0.046225)
#  3. feature 'Estimated Cost' (0.031162)
#  4. feature 'Street Suffix_St' (0.015425)
#  5. feature 'Street Suffix_Av' (0.011000)
#  6. feature 'Current Status_complete' (0.005402)
#  7. feature 'Permit Type Definition_sign - erect' (0.005110)
#  8. feature 'Current Status_issued' (0.004178)
#  9. feature 'Permit Type' (0.003147)
# 10. feature 'Permit Type Definition_otc alterations permit' (0.002106)
# 11. feature 'Permit Type Definition_additions alterations or repairs' (0.001265)
# 12. feature 'Street Suffix_Pz' (0.001109)
# 13. feature 'Street Suffix_Wy' (0.000936)
# 14. feature 'Street Suffix_Dr' (0.000768)
# 15. feature 'Current Status_filed' (0.000762)
# 16. feature 'Street Suffix_Bl' (0.000615)
# 17. feature 'Street Suffix_Tr' (0.000388)
# 18. feature 'Permit Type Definition_new construction wood frame' (0.000320)
# 19. feature 'Current Status_expired' (0.000278)
# ...

# %%
feature_names[[1,0,1]]
# Out:
# Index(['Street Number', 'Permit Type', 'Street Number'], dtype='object')

# %%
d_first = 20
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'r')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 20)

# %% [markdown]
# # Extremely Randomized Trees

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train)

err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.00010055304172951231

# %% [markdown]
# # AdaBoost

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
ada.fit(X_train, y_train)

err_train = np.mean(y_train != ada.predict(X_train))
err_test = np.mean(y_test != ada.predict(X_test))

print(err_train, err_test)
# Out:
# 0.022387416505063564 0.022322775263951735

# %% [markdown]
# # GBT

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train)

err_train = np.mean(y_train != gbt.predict(X_train))
err_test = np.mean(y_test != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.0
